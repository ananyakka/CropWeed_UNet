# %%
# %run unet.py
# Out:
# Using TensorFlow backend.
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:128: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge7 = merge([conv3,up7], mode = 'concat', concat_axis = 3)
# /usr/local/lib/python3.5/dist-packages/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:133: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge8 = merge([conv2,up8], mode = 'concat', concat_axis = 3)
# ...

# %%
# %run unet.py
# Out:
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:128: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge7 = merge([conv3,up7], mode = 'concat', concat_axis = 3)
# /usr/local/lib/python3.5/dist-packages/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:133: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge8 = merge([conv2,up8], mode = 'concat', concat_axis = 3)
# ...

# %%
actual_label = cv2.imread('/extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/newIMG_1413/newIMG_1413_rotated15.png')

# %%
test_img = cv2.imread('/extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1413/newIMG_1413_rotated15.png')
test_img_exp=np.expand_dims(test_img, axis=0)

# %%
predicted_label = model.predict(test_img_exp)

# %%
predicted_label = array_to_img(predicted_label[0])
# '''
predicted_label.save('/home/ananya/Desktop')
# predicted_label.save(path, 'jpg')
# cv2.imwrite(path, predicted_label[0])

predicted_image = cv2.imread(path)

# %%
recall_score= recall_score_class(actual_label, predicted_image).eval()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ff24c6b53f5d> in <module>()
# ----> 1 recall_score= recall_score_class(actual_label, predicted_image).eval()
#
# NameError: name 'predicted_image' is not defined

# %%
# %run unet.py
# Out:
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:128: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge7 = merge([conv3,up7], mode = 'concat', concat_axis = 3)
# /usr/local/lib/python3.5/dist-packages/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:133: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge8 = merge([conv2,up8], mode = 'concat', concat_axis = 3)
# ...

# %%
# %run unet.py
# Out:
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:128: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge7 = merge([conv3,up7], mode = 'concat', concat_axis = 3)
# /usr/local/lib/python3.5/dist-packages/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:133: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge8 = merge([conv2,up8], mode = 'concat', concat_axis = 3)
# ...

# %%
# %run unet.py
# Out:
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:119: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge7 = merge([conv3,up7], mode = 'concat', concat_axis = 3)
# /usr/local/lib/python3.5/dist-packages/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:124: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge8 = merge([conv2,up8], mode = 'concat', concat_axis = 3)
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:129: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge9 = merge([conv1,up9], mode = 'concat', concat_axis = 3)
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:140: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("co..., inputs=Tensor("in...)`
#   model = Model(input = inputs, output =out)
# (?, 200, 200, 3)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 200, 200, 3)  0
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 200, 200, 25) 700         input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 200, 200, 25) 5650        conv2d_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 100, 100, 25) 0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 100, 100, 50) 11300       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 100, 100, 50) 22550       conv2d_57[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 50, 50, 50)   0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 50, 50, 100)  45100       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 50, 50, 100)  90100       conv2d_59[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 25, 25, 100)  0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 25, 25, 200)  180200      max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 25, 25, 200)  360200      conv2d_61[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 25, 25, 200)  0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 50, 50, 200)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 50, 50, 100)  80100       up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# merge_10 (Merge)                (None, 50, 50, 200)  0           conv2d_60[0][0]
#                                                                  conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 50, 50, 100)  180100      merge_10[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 50, 50, 100)  90100       conv2d_64[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 100, 100, 100 0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 100, 100, 50) 20050       up_sampling2d_11[0][0]
# __________________________________________________________________________________________________
# merge_11 (Merge)                (None, 100, 100, 100 0           conv2d_58[0][0]
#                                                                  conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 100, 100, 50) 45050       merge_11[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 100, 100, 50) 22550       conv2d_67[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 200, 200, 50) 0           conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 200, 200, 25) 5025        up_sampling2d_12[0][0]
# __________________________________________________________________________________________________
# merge_12 (Merge)                (None, 200, 200, 50) 0           conv2d_56[0][0]
#                                                                  conv2d_69[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 200, 200, 25) 11275       merge_12[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 200, 200, 25) 5650        conv2d_70[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 200, 200, 3)  78          conv2d_71[0][0]
# ==================================================================================================
# Total params: 1,175,778
# Trainable params: 1,175,778
# Non-trainable params: 0
# __________________________________________________________________________________________________
# got unet
# Fitting model...
# Epoch 1/500
# 1999/2000 [============================>.] - ETA: 0s - loss: 225.1254 - acc: 0.2624Epoch 00001: val_loss improved from inf to 126.37045, saving model to unet.hdf5
# 2000/2000 [==============================] - 996s 498ms/step - loss: 225.0902 - acc: 0.2625 - val_loss: 126.3704 - val_acc: 0.2389
# Epoch 2/500
# 1999/2000 [============================>.] - ETA: 0s - loss: 152.1796 - acc: 0.2885Epoch 00002: val_loss improved from 126.37045 to 114.01339, saving model to unet.hdf5
# 2000/2000 [==============================] - 996s 498ms/step - loss: 152.1900 - acc: 0.2885 - val_loss: 114.0134 - val_acc: 0.2295
# Epoch 3/500
#  176/2000 [=>............................] - ETA: 13:59 - loss: 130.4305 - acc: 0.2422
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py in <module>()
#     380         # myunet.train() # comment for kfold cross-validation
#     381         # myunet.train_kfold()# uncomment for kfold cross-validation
# --> 382         myunet.train_batch()
#     383         myunet.save_img()# comment for kfold cross-validation
#     384
#
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py in train_batch(self)
#     283                 print('Fitting model...')
#     284                 early_stopping = EarlyStopping(monitor='val_loss', min_delta = 0.0001, patience=5)
# --> 285                 model.fit_generator(training_generator, epochs=500, steps_per_epoch=2000, verbose=1, callbacks=[model_checkpoint, early_stopping], validation_data = validation_generator, validation_steps = 610 )
#     286                 #steps are found by dividing total images by batch size; (68080/32 ~= 2127), (19536/32 ~= 610)
#     287
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2145                     outs = self.train_on_batch(x, y,
#    2146                                                sample_weight=sample_weight,
# -> 2147                                                class_weight=class_weight)
#    2148
#    2149                     if not isinstance(outs, list):
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1837             ins = x + y + sample_weights
#    1838         self._make_train_function()
# -> 1839         outputs = self.train_function(ins)
#    1840         if len(outputs) == 1:
#    1841             return outputs[0]
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# %run unet.py
# Out:
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:119: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge7 = merge([conv3,up7], mode = 'concat', concat_axis = 3)
# /usr/local/lib/python3.5/dist-packages/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:124: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge8 = merge([conv2,up8], mode = 'concat', concat_axis = 3)
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:129: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   merge9 = merge([conv1,up9], mode = 'concat', concat_axis = 3)
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py:140: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("co..., inputs=Tensor("in...)`
#   model = Model(input = inputs, output =out)
# (?, 200, 200, 3)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 200, 200, 3)  0
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 200, 200, 25) 700         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 200, 200, 25) 5650        conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 100, 100, 25) 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 100, 100, 50) 11300       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 100, 100, 50) 22550       conv2d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 50, 50, 50)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 50, 50, 100)  45100       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 50, 50, 100)  90100       conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 25, 25, 100)  0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 25, 25, 200)  180200      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 25, 25, 200)  360200      conv2d_25[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 25, 25, 200)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 50, 50, 200)  0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 50, 50, 100)  80100       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# merge_4 (Merge)                 (None, 50, 50, 200)  0           conv2d_24[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 50, 50, 100)  180100      merge_4[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 50, 50, 100)  90100       conv2d_28[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 100, 100, 100 0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 100, 100, 50) 20050       up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# merge_5 (Merge)                 (None, 100, 100, 100 0           conv2d_22[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 100, 100, 50) 45050       merge_5[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 100, 100, 50) 22550       conv2d_31[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 200, 200, 50) 0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 200, 200, 25) 5025        up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# merge_6 (Merge)                 (None, 200, 200, 50) 0           conv2d_20[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 200, 200, 25) 11275       merge_6[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 200, 200, 25) 5650        conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 200, 200, 3)  78          conv2d_35[0][0]
# ==================================================================================================
# Total params: 1,175,778
# Trainable params: 1,175,778
# Non-trainable params: 0
# __________________________________________________________________________________________________
# got unet
# Fitting model...
# Epoch 1/500
# 1999/2000 [============================>.] - ETA: 0s - loss: 213.6499 - acc: 0.3340Epoch 00001: val_loss improved from inf to 123.23501, saving model to unet.hdf5
# 2000/2000 [==============================] - 1006s 503ms/step - loss: 213.6202 - acc: 0.3340 - val_loss: 123.2350 - val_acc: 0.2386
# Epoch 2/500
# 1999/2000 [============================>.] - ETA: 0s - loss: 151.8180 - acc: 0.2877Epoch 00002: val_loss improved from 123.23501 to 113.71841, saving model to unet.hdf5
# 2000/2000 [==============================] - 1001s 500ms/step - loss: 151.8283 - acc: 0.2877 - val_loss: 113.7184 - val_acc: 0.2117
# Epoch 3/500
# 1999/2000 [============================>.] - ETA: 0s - loss: 140.3508 - acc: 0.2665Epoch 00003: val_loss improved from 113.71841 to 107.45186, saving model to unet.hdf5
# 2000/2000 [==============================] - 995s 497ms/step - loss: 140.4163 - acc: 0.2667 - val_loss: 107.4519 - val_acc: 0.2030
# Epoch 4/500
# 1999/2000 [============================>.] - ETA: 0s - loss: 177.3022 - acc: 0.3275Epoch 00004: val_loss did not improve
# 2000/2000 [==============================] - 998s 499ms/step - loss: 177.3346 - acc: 0.3276 - val_loss: 118.9162 - val_acc: 0.2231
# Epoch 5/500
# 1999/2000 [============================>.] - ETA: 0s - loss: 131.7166 - acc: 0.2491Epoch 00005: val_loss did not improve
# 2000/2000 [==============================] - 1001s 500ms/step - loss: 131.7174 - acc: 0.2491 - val_loss: 137.6364 - val_acc: 0.2596
# Epoch 6/500
# 1308/2000 [==================>...........] - ETA: 5:21 - loss: 162.7323 - acc: 0.3067
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py in <module>()
#     380         # myunet.train() # comment for kfold cross-validation
#     381         # myunet.train_kfold()# uncomment for kfold cross-validation
# --> 382         myunet.train_batch()
#     383         myunet.save_img()# comment for kfold cross-validation
#     384
#
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/unet.py in train_batch(self)
#     283                 print('Fitting model...')
#     284                 early_stopping = EarlyStopping(monitor='val_loss', min_delta = 0.0001, patience=5)
# --> 285                 model.fit_generator(training_generator, epochs=500, steps_per_epoch=2000, verbose=1, callbacks=[model_checkpoint, early_stopping], validation_data = validation_generator, validation_steps = 610 )
#     286                 #steps are found by dividing total images by batch size; (68080/32 ~= 2127), (19536/32 ~= 610)
#     287
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2145                     outs = self.train_on_batch(x, y,
#    2146                                                sample_weight=sample_weight,
# -> 2147                                                class_weight=class_weight)
#    2148
#    2149                     if not isinstance(outs, list):
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1837             ins = x + y + sample_weights
#    1838         self._make_train_function()
# -> 1839         outputs = self.train_function(ins)
#    1840         if len(outputs) == 1:
#    1841             return outputs[0]
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
import os
import PIL
from PIL import Image
from numpy import array
from glob import glob
import numpy as np
import math
import random
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img


filepath = '/extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/'
labelpath = '/extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/'

batch_size = 32

#Make a list of all files
file_list = list(os.listdir(filepath))
no_of_images = len(file_list)

#Shuffle the indices of the file list
indices_shuffled = np.random.choice(no_of_images, no_of_images, replace =False)

#Split the indices into train, validation and test data
x_train_size1 = int(no_of_images *0.7)
x_train_size2 = int(no_of_images *0.6)

x_val_size1 = int(no_of_images*0.9)
x_val_size2 = int(no_of_images*0.8)


x_train, x_val, x_test = np.split(indices_shuffled, [x_train_size1, x_val_size1])

# %%
# %run data_generator.py
# Out:
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted56.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted56.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted102.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted102.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted218.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted218.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted146.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted146.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted162.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted162.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted236.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted236.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted10.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted10.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted177.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted177.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted142.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted142.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_rotated17.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_rotated17.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted186.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted186.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted48.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted48.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted155.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted155.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted147.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted147.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted191.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted191.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted148.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted148.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_spnoise.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_spnoise.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted32.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted32.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted181.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted181.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted37.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted37.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_rotated23.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_rotated23.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted31.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted31.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted72.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted72.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted124.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted124.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted45.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted45.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted239.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted239.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_rotated40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_rotated40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted127.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted127.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted173.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted173.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted7.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted7.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted22.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted22.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1751/newIMG_1751_shifted139.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1751/newIMG_1751_shifted139.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_rotated16.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_rotated16.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted151.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted151.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_rotated45.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_rotated45.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_rotated6.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_rotated6.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted112.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted112.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_rotated14.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_rotated14.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted74.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted74.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted102.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted102.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_rotated46.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_rotated46.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted8.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted8.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted30.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted30.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted5.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted5.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_rotated32.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_rotated32.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted17.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted17.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_spnoise.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_spnoise.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted183.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted183.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted190.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted190.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted149.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted149.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted33.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted33.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted36.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted36.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_rotated21.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_rotated21.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted238.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted238.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted156.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted156.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted158.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted158.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted127.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted127.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted84.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted84.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted208.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted208.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_rotated7.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_rotated7.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_rotated40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_rotated40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted154.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted154.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted91.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted91.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1986/newIMG_1986_shifted173.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1986/newIMG_1986_shifted173.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted31.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted31.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted100.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted100.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_rotated42.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_rotated42.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_rotated47.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_rotated47.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_rotated5.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_rotated5.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted154.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted154.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_rotated9.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_rotated9.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted8.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted8.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_rotated16.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_rotated16.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted138.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted138.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted193.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted193.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted203.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted203.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_rotated46.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_rotated46.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted194.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted194.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted27.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted27.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted41.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted41.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted201.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted201.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted95.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted95.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_hflipped.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_hflipped.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted175.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted175.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted129.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted129.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_rotated35.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_rotated35.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted26.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted26.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted128.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted128.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted111.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted111.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted141.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted141.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted18.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted18.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted159.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted159.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted153.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted153.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted20.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted20.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1722/newIMG_1722_shifted64.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1722/newIMG_1722_shifted64.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted205.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted205.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_rotated40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_rotated40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted201.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted201.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted158.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted158.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted31.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted31.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted48.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted48.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted166.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted166.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted179.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted179.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted177.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted177.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted1.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted1.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted34.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted34.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted93.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted93.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted143.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted143.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted30.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted30.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted24.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted24.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_rotated2.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_rotated2.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted240.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted240.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted50.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted50.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted168.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted168.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted124.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted124.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted113.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted113.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted218.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted218.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted69.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted69.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted188.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted188.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted28.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted28.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_rotated29.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_rotated29.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted180.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted180.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted142.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted142.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted228.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted228.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted133.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted133.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1443/newIMG_1443_shifted207.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1443/newIMG_1443_shifted207.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted58.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted58.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_rotated45.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_rotated45.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted236.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted236.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted162.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted162.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted22.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted22.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted172.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted172.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted86.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted86.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_rotated2.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_rotated2.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted109.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted109.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_gnoise.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_gnoise.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted143.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted143.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_rotated41.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_rotated41.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted118.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted118.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted178.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted178.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted103.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted103.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted25.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted25.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_rotated6.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_rotated6.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted62.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted62.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted107.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted107.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted232.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted232.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_rotated25.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_rotated25.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted185.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted185.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted38.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted38.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted165.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted165.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted134.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted134.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted64.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted64.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted81.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted81.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted237.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted237.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted115.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted115.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted164.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted164.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted52.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted52.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1460/newIMG_1460_shifted92.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1460/newIMG_1460_shifted92.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted63.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted63.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted199.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted199.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted2.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted2.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_rotated49.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_rotated49.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted104.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted104.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted129.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted129.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted94.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted94.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted170.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted170.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted122.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted122.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_rotated40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_rotated40.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted216.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted216.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted152.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted152.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_rotated8.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_rotated8.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted78.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted78.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted59.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted59.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted57.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted57.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted111.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted111.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted28.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted28.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_shifted149.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_shifted149.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_rotated31.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_rotated31.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_images/newIMG_1817/newIMG_1817_rotated33.png
# /extend_sda/Ananya_files/Weeding Bot Project/Farm Photos/Labelled Data/Augmented_train_labels/ newIMG_1817/newIMG_1817_rotated33.png
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /extend_sda/Ananya_files/Weeding Bot Project/Codes/Keras TF/Segmentation/UNet/data_generator.py in <module>()
#      77                         label = load_img(os.path.join(labelpath, file_list[index])+'/'+ label_folder[iImage], grayscale = False)
#      78                         print(labelpath, file_list[index]+'/'+ label_folder[iImage])
# ---> 79                         img = img_to_array(img)
#      80                         label = img_to_array(label)
#      81
#
# /usr/local/lib/python3.5/dist-packages/keras/preprocessing/image.py in img_to_array(img, data_format)
#     305     # or (channel, height, width)
#     306     # but original PIL image has format (width, height, channel)
# --> 307     x = np.asarray(img, dtype=K.floatx())
#     308     if len(x.shape) == 3:
#     309         if data_format == 'channels_first':
#
# /usr/local/lib/python3.5/dist-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# TypeError: float() argument must be a string or a number, not 'PngImageFile'
